# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloBarretoDev/GenIaAtividade1/blob/main/AtividadeGenIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefas para criar um RAG
# 1. Carregar os dados
# 2. Criar coluna para representar cada review
# 3. Criar coluna com embeddings
# 4. Criar função para buscar reviews relevantes a partir de uma query de busca
# 5. Criar prompt para perguntar ao gpt
# 6. Enviar prompt para o gpt e mostrar as respostas

# %% [markdown]
# ## 1. Carregar os dados

# %%
import pandas as pd;

df = pd.read_csv("/content/Games.csv");

# %% [markdown]
# ## 2. Criar coluna para representar cada venda

# %%
df["Name"] = df["Name"].astype(str);
df["Sales"] = df["Sales"].astype(float);
df["Publisher"] = df["Publisher"].astype(str);
df["texto_para_promtp"] = df["Name"] + " da publisher "+ df["Publisher"] + " vendeu "+ df["Sales"].astype(str) + " unidades na plataforma PC"

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.0)

# %% [markdown]
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.1

# %% [markdown]
# ]
# 9s
# !pip install openai
# output
# Collecting openai
#   Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.1

# %%
import os
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

os.environ['OPENAI_API_KEY']
os.environ['OPENAI_API_BASE']
# Out:
# 'https://openai-portodigital.openai.azure.com/'

# %% [markdown]
# https://openai-portodigital.openai.azure.com/

# %%
import openai

openai.api_type = "azure"
openai.api_key  = os.environ['OPENAI_API_KEY']
openai.api_base = os.environ['OPENAI_API_BASE']
openai.api_version = "2023-05-15"

response = openai.Embedding.create(
    input="OI BRASIL",
    engine="text-similarity-ada-001"
)

# %%
embeddings = response['data'][0]['embedding']
embeddings
# Out:
# [-0.019395481795072556,
#  0.030103718861937523,
#  -0.0001273331290576607,
#  0.032396186143159866,
#  0.02742917463183403,
#  -0.0012279280927032232,
#  0.02847486175596714,
#  -0.013141470029950142,
#  0.050112538039684296,
#  -0.026041626930236816,
#  0.00418526167050004,
#  -0.026262830942869186,
#  0.03752407431602478,
#  -0.019174279645085335,
#  -0.008516316302120686,
#  -0.031229844316840172,
#  -0.021336035802960396,
#  -0.007430410478264093,
#  -0.004117392469197512,
#  -0.01598694548010826,
#  0.043154697865247726,
#  -0.013915680348873138,
#  0.028434641659259796,
#  -0.00904921442270279,
#  -0.020421059802174568,
#  0.018420178443193436,
#  -0.031873345375061035,
#  0.0047282143495976925,
#  -0.01569535955786705,
#  -0.01875198259949684,
#  -0.04987122491002083,
#  0.015946727246046066,
#  0.0006541828042827547,
#  0.06603915244340897,
#  0.03975621610879898,
#  -0.02026018500328064,
#  -0.04027905687689781,
#  -0.011854470707476139,
#  0.011502556502819061,
#  0.01390562579035759,
#  -0.045608039945364,
#  -0.00938604585826397,
#  0.001997111365199089,
#  0.008687245659530163,
#  0.0128901032730937,
#  -0.022804019972682,
#  -0.027911799028515816,
#  -0.04395907372236252,
#  -0.007309754379093647,
#  -0.015504320152103901,
#  -0.01229687687009573,
#  0.028133001178503036,
#  -0.005866907071322203,
#  0.002352795796468854,
#  0.0010104955872520804,
#  -0.023346973583102226,
#  0.022884458303451538,
#  -0.05373222380876541,
#  -0.015554593876004219,
#  0.0508364737033844,
#  -0.008466042578220367,
#  -0.005052478052675724,
#  0.05522031709551811,
#  -0.038227904587984085,
#  0.02041100524365902,
#  0.0016313722589984536,
#  -0.0005687180091626942,
#  -0.028193330392241478,
#  -0.02662479877471924,
#  -0.015142352320253849,
#  0.022381722927093506,
#  0.0314108282327652,
#  -0.022783910855650902,
#  -0.29842299222946167,
#  -0.05546163022518158,
#  -0.01748509332537651,
#  -0.0156853049993515,
#  0.036297403275966644,
#  -0.003124492708593607,
#  -0.016177983954548836,
#  -0.017012523487210274,
#  0.02415134757757187,
#  0.008903421461582184,
#  0.04987122491002083,
#  -0.027690595015883446,
#  0.022924676537513733,
#  0.0004945647087879479,
#  -0.04343622922897339,
#  -0.02489539422094822,
#  0.015896452590823174,
#  -0.03191356360912323,
#  -0.018701709806919098,
#  -0.0381273552775383,
#  0.04052037000656128,
#  0.004016845487058163,
#  -0.01853078044950962,
#  0.014971422031521797,
#  -0.0717904344201088,
#  0.00016260307165794075,
#  -0.016057327389717102,
#  0.017997881397604942,
#  0.007510847877711058,
#  0.026343267410993576,
#  0.009969217702746391,
#  -0.005384282674640417,
#  -0.045326508581638336,
#  -0.02234150469303131,
#  -0.028515079990029335,
#  0.003602090058848262,
#  0.017283998429775238,
#  0.014378195628523827,
#  -0.004607558250427246,
#  -0.03086787462234497,
#  -0.017002468928694725,
#  0.04363732039928436,
#  -0.0027801196556538343,
#  -0.004124933388084173,
#  0.026665018871426582,
#  -0.014901039190590382,
#  -0.02332686260342598,
#  -0.003049082588404417,
#  -0.0411035418510437,
#  -0.06394778192043304,
#  0.02863573655486107,
#  -0.11261244118213654,
#  0.022683363407850266,
#  -0.025136705487966537,
#  0.03191356360912323,
#  0.023266535252332687,
#  0.024573644623160362,
#  -0.022442052140831947,
#  -0.0426318533718586,
#  -0.039575230330228806,
#  -0.027791142463684082,
#  0.009853589348495007,
#  0.026122065261006355,
#  -0.06611958891153336,
#  0.007189097814261913,
#  -0.026182392612099648,
#  -0.0343669056892395,
#  -0.0224219411611557,
#  0.0011148129124194384,
#  -0.016328804194927216,
#  -0.029037922620773315,
#  0.017374491319060326,
#  0.014076555147767067,
#  -0.029319453984498978,
#  ...]

# %% [markdown]
# ## 4. Criar função para buscar reviews relevantes a partir de uma query de **busca**

# %%
import openai
import time

def text_embedding(text):
    """
    Recebe string, faz chamada ao modelo de embeddings da openai e retorna os embeddings da string
    """
    response = None
    retry_count = 0

    while response is None:
        try:
            response = openai.Embedding.create(engine="text-similarity-ada-001", input=text)
        except Exception as e:
            # Verifique se o erro é devido ao limite de chamadas
            if "call rate limit" in str(e):
                # Espere por um tempo exponencialmente crescente antes de tentar novamente
                time.sleep(2 ** retry_count)
                retry_count += 1
                continue
            else:
                # Se ocorrer outro tipo de erro, lide com ele de acordo com sua lógica de tratamento de erros
                print("Erro ao fazer chamada para a API: ", str(e))
                return None

    return response["data"][0]["embedding"]

# %%
# Cria sample das linhas para fazer menos chamadas ao modelo
df_menor = df.sample(100);

# %%
df_menor.shape
# Out:
# (100, 9)

# %% [markdown]
# (100, 8)

# %%
# criar coluna com os embeddings
df_menor["embeddings"] = df_menor["texto_para_promtp"].apply(lambda linha: text_embedding(linha))

# %%
from scipy import spatial

def strings_ranked_by_relatedness(
    query: str,
    df: pd.DataFrame,
    relatedness_fn=lambda x, y: 1 - spatial.distance.cosine(x, y),
    top_n: int = 10
) -> tuple[list[str], list[float]]:
    """
    Retorna as linhas do dataframe mais semelhantes a string de busca
    """

    query_embedding = text_embedding(query)

    strings_and_relatednesses = [ ]
    for i, row in df.iterrows():

        #relatedness = relatedness_fn(np.array(query_embedding).flatten(), np.array(row["embedding"]).flatten())
        relatedness = relatedness_fn(query_embedding, row["embeddings"])
        item = (row["texto_para_promtp"], relatedness)
        strings_and_relatednesses.append(item)

    strings_and_relatednesses.sort(key=lambda x: x[1], reverse=True)
    strings, relatednesses = zip(*strings_and_relatednesses)
    return strings[:top_n], relatednesses[:top_n]

# %%
strings, relatednesses = strings_ranked_by_relatedness("Qual o game mais vendido",
                              df_menor)
for string, relatedness in zip(strings, relatednesses):
    print(f"{relatedness=:.3f}")
    display(string)
# Out:
# relatedness=0.811
# 'Quake II da publisher Activision vendeu 1.0 unidades na plataforma PC'
# relatedness=0.809
# 'Doom da publisher id Software vendeu 2.0 unidades na plataforma PC'
# relatedness=0.808
# 'Dark Souls II da publisher Bandai Namco Games vendeu 2.7 unidades na plataforma PC'
# relatedness=0.808
# 'Black & White da publisher EA Games vendeu 2.0 unidades na plataforma PC'
# relatedness=0.806
# 'Supreme Commander da publisher THQ vendeu 1.0 unidades na plataforma PC'
# relatedness=0.806
# 'Spore da publisher Electronic Arts vendeu 2.0 unidades na plataforma PC'
# relatedness=0.802
# 'Lords of the Realm II da publisher Impressions Game vendeu 2.5 unidades na plataforma PC'
# relatedness=0.801
# 'Unreal da publisher GT Interactive vendeu 1.0 unidades na plataforma PC'
# relatedness=0.801
# 'Guild Wars 2 da publisher NCsoft vendeu 5.0 unidades na plataforma PC'
# relatedness=0.801
# 'Psychonauts da publisher THQ vendeu 1.0 unidades na plataforma PC'

# %% [markdown]
# **negrito**## 5. Criar prompt para perguntar ao gpt
# * O modelo possui um limite de tokens, vamos verificar se o limite foi atingido ou não para criar o prompt

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.5.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2023.7.22)

# %%
import tiktoken

def num_tokens(text: str) -> int:
    encoding = tiktoken.encoding_for_model("gpt-3.5-turbo-16k")
    return len(encoding.encode(text))

# %%
num_tokens("oi brasil")
# Out:
# 3

# %% [markdown]
# 3

# %%
num_tokens("Quais os jogos com mais sales de cada publisher")
# Out:
# 11

# %%
def montar_query(query: str, df: pd.DataFrame, token_budget: int) -> str:
    linhas, relatednesses = strings_ranked_by_relatedness(query, df)
    introducao = """
    Use o conteúdo abaixo com reviews de jogos para responder a pergunta a seguir.
    O conteúdo das vendas deve ser a sua única fonte para dar as respostas.
    Se você não conseguir encontrar a resposta no conteúdo, escreva "Não consegui encontrar uma resposta."
    """
    pergunta = f"\n\Pergunta: {query}"
    messagem = introducao
    for linha in linhas:
        proxima_linha = f'\n\nSeção com dados das sales de games:\n"""\n{linha}\n"""'
        if num_tokens(messagem + proxima_linha + pergunta) > token_budget:
            break
        else:
            messagem = messagem + proxima_linha

    return messagem + pergunta

# %%
from pprint import pprint

prompt = montar_query(query="Qual game com mais sales de cada publisher",
             df=df_menor,
             token_budget=16000)
pprint(prompt)
# Out:
# ('\n'
#  '    Use o conteúdo abaixo com reviews de jogos para responder a pergunta a '
#  'seguir.\n'
#  '    O conteúdo das vendas deve ser a sua única fonte para dar as respostas.\n'
#  '    Se você não conseguir encontrar a resposta no conteúdo, escreva "Não '
#  'consegui encontrar uma resposta."\n'
#  '    \n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Doom da publisher id Software vendeu 2.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Quake II da publisher Activision vendeu 1.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Terraria da publisher Re-Logic vendeu 17.2 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Unreal da publisher GT Interactive vendeu 1.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Spore da publisher Electronic Arts vendeu 2.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Black & White da publisher EA Games vendeu 2.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Supreme Commander da publisher THQ vendeu 1.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Tropico da publisher Gathering of Developers vendeu 1.0 unidades na '
#  'plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'The Witcher da publisher Atari, Inc vendeu 2.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\n'
#  'Seção com dados das sales de games:\n'
#  '"""\n'
#  'Mordhau da publisher Triternion vendeu 1.0 unidades na plataforma PC\n'
#  '"""\n'
#  '\\Pergunta: Qual game com mais sales de cada publisher')

# %% [markdown]
# ## 6. Enviar prompt para o gpt e mostrar as respostas

# %%
def perguntar(
    query: str,
    df: pd.DataFrame = df,
    model: str = "gpt-35-turbo-16k",
    print_message: bool = False,
) -> str:
    message = montar_query(query, df, token_budget=16000)
    if print_message:
        print(message)
    messages = [
        {"role": "system", "content": "Você responde perguntas sobre sales de jogos."},
        {"role": "user", "content": message},
    ]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
        engine="gpt-35-turbo-16k"
    )
    response_message = response["choices"][0]["message"]["content"]
    return response_message

# %%
resposta = perguntar("Qual game com mais sales de cada publisher",
    df_menor)
print(resposta)
# Out:
# - id Software: Doom (2.0 unidades vendidas)
# - Activision: Quake II (1.0 unidades vendidas)
# - Re-Logic: Terraria (17.2 unidades vendidas)
# - GT Interactive: Unreal (1.0 unidades vendidas)
# - Electronic Arts: Spore (2.0 unidades vendidas)
# - EA Games: Black & White (2.0 unidades vendidas)
# - THQ: Supreme Commander (1.0 unidades vendidas)
# - Gathering of Developers: Tropico (1.0 unidades vendidas)
# - Atari, Inc: The Witcher (2.0 unidades vendidas)
# - Triternion: Mordhau (1.0 unidades vendidas)

# %% [markdown]
# 2s
# resposta = perguntar("Qual game com mais sales de cada publisher",
#     df_menor)
# print(resposta)
# output
# - id Software: Doom (2.0 unidades vendidas)
# - Activision: Quake II (1.0 unidades vendidas)
# - Re-Logic: Terraria (17.2 unidades vendidas)
# - GT Interactive: Unreal (1.0 unidades vendidas)
# - Electronic Arts: Spore (2.0 unidades vendidas)
# - EA Games: Black & White (2.0 unidades vendidas)
# - THQ: Supreme Commander (1.0 unidades vendidas)
# - Gathering of Developers: Tropico (1.0 unidades vendidas)
# - Atari, Inc: The Witcher (2.0 unidades vendidas)
# - Triternion: Mordhau (1.0 unidades vendidas)

# %%
montar_query(query="Qual game com mais sales de cada publisher",
             df=df_menor,
             token_budget=16000)
# Out:
# '\n    Use o conteúdo abaixo com reviews de jogos para responder a pergunta a seguir.\n    O conteúdo das vendas deve ser a sua única fonte para dar as respostas.\n    Se você não conseguir encontrar a resposta no conteúdo, escreva "Não consegui encontrar uma resposta."\n    \n\nSeção com dados das sales de games:\n"""\nDoom da publisher id Software vendeu 2.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nQuake II da publisher Activision vendeu 1.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nTerraria da publisher Re-Logic vendeu 17.2 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nUnreal da publisher GT Interactive vendeu 1.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nSpore da publisher Electronic Arts vendeu 2.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nBlack & White da publisher EA Games vendeu 2.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nSupreme Commander da publisher THQ vendeu 1.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nTropico da publisher Gathering of Developers vendeu 1.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nThe Witcher da publisher Atari, Inc vendeu 2.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nMordhau da publisher Triternion vendeu 1.0 unidades na plataforma PC\n"""\n\\Pergunta: Qual game com mais sales de cada publisher'

# %% [markdown]
# \n    Use o conteúdo abaixo com reviews de jogos para responder a pergunta a seguir.\n    O conteúdo das vendas deve ser a sua única fonte para dar as respostas.\n    Se você não conseguir encontrar a resposta no conteúdo, escreva "Não consegui encontrar uma resposta."\n    \n\nSeção com dados das sales de games:\n"""\nDoom da publisher id Software vendeu 2.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nQuake II da publisher Activision vendeu 1.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nTerraria da publisher Re-Logic vendeu 17.2 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nUnreal da publisher GT Interactive vendeu 1.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nSpore da publisher Electronic Arts vendeu 2.0 unidades na plataforma PC\n"""\n\nSeção com dados das sales de games:\n"""\nBlack & White da publisher EA Games vendeu 2.0 unidades na plataforma PC\n"""\n

# %%
resposta = perguntar("Existe algum jogo com 2 sales?",
    df_menor)
print(resposta)
# Out:
# Sim, vários jogos têm 2 sales. Alguns exemplos são Black & White da EA Games, Doom da id Software, Spore da Electronic Arts, Far Cry da Ubisoft, Baldur's Gate da Interplay Entertainment e Battlefield 1942 da Electronic Arts.

# %% [markdown]
# Sim, vários jogos têm 2 sales. Alguns exemplos são Black & White da EA Games, Doom da id Software, Spore da Electronic Arts, Far Cry da Ubisoft, Baldur's Gate da Interplay Entertainment e Battlefield 1942 da Electronic Arts.
